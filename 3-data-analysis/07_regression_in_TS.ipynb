# %% [markdown]
# _____
#
# <table align="left" width=100%>
#     <td>
#         <div style="text-align: center;">
#           <img src="./images/bar.png" alt="entidades financiadoras"/>
#         </div>
#     </td>
#     <td>
#         <p style="text-align: center; font-size:24px;"><b>Introduction to Data Science</b></p>
#         <p style="text-align: center; font-size:18px;"><b>Master in Electrical and Computer Engineering</b></p>
#         <p style="text-align: center; font-size:14px;"><b>Pedro Cardoso (pcardoso@ualg.pt)</b></p>
#     </td>
# </table>
#
# _____
#
# __Lesson:__ Time Series Regression Models
#
# *__Summary:__ This lesson introduces various regression techniques specifically designed for time series data. Students will learn about the challenges of applying standard regression methods to time series (like autocorrelation and non-stationarity) and how specialized approaches address these issues. The lesson will likely cover models such as Autoregressive (AR), Moving Average (MA), Autoregressive Moving Average (ARMA), and Autoregressive Integrated Moving Average (ARIMA) models. It will explain the underlying principles of each model, including model order selection and parameter estimation. Students will gain practical experience in fitting these models to time series data, evaluating their performance using appropriate metrics, and making predictions. The lesson may also touch upon more advanced techniques like SARIMA (Seasonal ARIMA) for data with seasonal components.*

# %% [markdown]
# # Regression in Time Series
#
# **Time series regression** is a statistical technique used to model the relationship between a dependent variable and one or more independent variables that change over time. In other words, it is a way of **predicting future values of a variable based on its past values and the values of other related variables**.
#
# In time series regression, the dependent variable is a time series, which means that it is **assumed** as a sequence of **observations taken at regular intervals over time**. The **independent variables** can also be time series or other types of variables that are believed to have an impact on the dependent variable.
#
# The goal of **time series regression is to identify the underlying patterns and trends** in the data and use this information to **make accurate predictions about future values of the dependent variable**. This is typically done by fitting a statistical model to the data and estimating the coefficients of the model using a variety of techniques, such as least squares or maximum likelihood estimation.
#
# We should distinguish between **time series regression** and **time series forecasting**.
#
# - In **time series forecasting**, the goal is to predict the future values of a variable based on its past values alone.
# - In **time series regression**, the goal is to predict the past, present or future values of a variable based on its past values and the values of other related variables.
#
# Both time series forecasting and time series regression are supervised learning problems.

# %% [markdown]
# ## Evaluate Models
#
# Evaluating a time series regression model involves assessing the model's performance and accuracy in predicting future values of the time series. Next, some common methods for evaluating time series regression models are listed.
#
# ### Train-test split
# When training a machine learning model, it's essential to evaluate its performance on data that hasn't been used during training. This is done to **avoid overfitting**, where the model performs well on the training data but poorly on new data. To achieve this, the original dataset is usually **split into a training set and a test set**. However, there are cases where a third subset, called the **validation set**, is added to the mix. Here are the main differences between two popular data splitting strategies: **train-test and train-validation-test**.
#
# One potential issue with the train-test split is that the test set might be too small to provide a reliable estimate of the model's performance. The smaller the test set, the more likely it is that the evaluation metric will be affected by chance. To mitigate this issue, the train-validation-test split is often used.

# %% [markdown]
# #### Train-Validation-Test Split
#
# The train-validation-test split involves dividing the original dataset into three subsets: a **training set, a validation set, and a test set**. The training set is used to train the model, the validation set is used to evaluate the model's performance during training and to tune the hyperparameters of the model, and the test set is used to evaluate the final performance of the model after training and tuning.
#
# During training, the model is evaluated on the validation set after every epoch (in the case o Neural Networks) or after a fixed number of iterations. The **hyperparameters of the model are then adjusted based on the performance on the validation set**. This process is **repeated until the best hyperparameters are found**. Once the model has been fully trained and tuned, it is **evaluated on the test set to obtain an estimate of its performance on new data**.
#
# One advantage of the train-validation-test split is that it provides a more accurate estimate of the model's performance on new data. By using a separate validation set, we can ensure that the model is not overfitting to the training data. By using a separate test set, we can ensure that the evaluation metric is not biased by chance.

# %% [markdown]
# #### Train-Test Split in time series
#
# In time series analysis, a common approach to model evaluation is also to use a train-test split. However, **the traditional random train-test split is NOT suitable for time series data**, as it violates the assumption that the data points are independent and identically distributed (iid). In time series data, the order of the data points matters, and the past observations can be used to predict the future ones.
#
# A more appropriate approach for time series data is to use a **"rolling window"** or **"walk-forward" validation** technique. This involves **training the model on a portion of the data and testing it on a subsequent portion**, sliding the window forward until the entire dataset has been used for testing. This allows for the evaluation of the model's performance on unseen data while maintaining the temporal ordering of the data.
#
# In the rolling window technique, the size of the test set can be chosen based on the application requirements and the available data. However, a common practice is to use a test set that is large enough to provide a reliable estimate of the model's performance but small enough to allow for multiple iterations of the rolling window approach. The performance metrics are then aggregated over the different iterations to obtain a more robust estimate of the model's performance.

# %% [markdown]
# #### Example using the airline passengers dataset
#
# Let us see some examples using the airline passengers dataset.

# %%
import pandas as pd

 # load the data
df_passengers = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=True)

# convert the Month column to a datetime object 
df_passengers['Month'] = pd.to_datetime(df_passengers['Month'])

# create new features from the Month column
df_passengers['Year'] = df_passengers['Month'].dt.year
df_passengers['Month'] = df_passengers['Month'].dt.month

# drop the Unnamed: 0 column
df_passengers.drop('Unnamed: 0', axis=1, inplace=True)

df_passengers

# %% [markdown]
# ##### Polynomial features
#
# Beside the use o month, year as features, and #passengers as targer, it is also possible to do some increase in the number os features using **polynomial features**. Polynomial features are a type of feature engineering technique used in machine learning to create non-linear models by adding polynomial terms to the original features.
#
# In simpler terms, polynomial features are created by taking the original features of a dataset and raising them to a power. For example, if we have a dataset with one feature $x$, we can create polynomial features by adding a new feature $x^2$. Obviously, we can also add higher order terms like $x^3$, $x^4$, and so on.
#
# The general formula for generating polynomial features is as follows:
# $$(x_1, x_2, \dots, x_n) \rightarrow (1, x_1, x_2, \dots, x_n, x_1^2, x_1x_2, \dots, x_1x_n, x_2^2, x_2x_3,\dots, x_n^2)$$
#
#
# The purpose of adding polynomial features is to **capture non-linear relationships between the features and the target variable**. In some cases, the relationship between the features and the target variable may not be linear, and adding polynomial features can help to capture these non-linear relationships. This also increases model flexibility since we are increasing the number of dimensions of the dataset. This increased dimensionality can lead to a more flexible model that can fit more complex relationships. On the other side, increased model complexity which can make it harder to interpret the model and identify the most important features; and increased computation time required to train the model, especially if we generate a large number of features.
#
# Overall, polynomial features can be a useful tool for improving the performance of machine learning models when the relationship between the features and the target variable is non-linear.

# %%
from sklearn.preprocessing import PolynomialFeatures

# get the features and target
X = df_passengers[['Month', 'Year']]
y = df_passengers['#Passengers']

# create the PolynomialFeatures model
poly_features_model = PolynomialFeatures(degree=5)

# fit and apply model
X = pd.DataFrame(poly_features_model.fit_transform(X),
                 columns = poly_features_model.get_feature_names_out(['Month', 'Year']))

X

# %% [markdown]
# ##### Model
#
# Now, we will use a pipeline to implement a ML solution, which starts by scaling data, before training the model.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor

# split the data into training and test sets, predicting the last year (12 month)
n = 12

X_train = X.iloc[:-n]
y_train = y[:-n]

X_test =  X.iloc[-n:]
y_test = y[-n:]

# fit a regression model to the training data with random search
from sklearn.model_selection import RandomizedSearchCV

# define the parameter grid
param_grid = {
    'MLPRegressor__hidden_layer_sizes': [(32,), (64,), (64, 32), (128, 64, 32)],
    'MLPRegressor__activation': ['relu', 'tanh'],
    'MLPRegressor__alpha': [1e-4, 1e-3, 1e-2],
    'MLPRegressor__learning_rate_init': [1e-1, 1e-2, 1e-3],
    'MLPRegressor__max_iter': [100000],
}

# perform random search
reg_model = Pipeline([
    ('scaler', StandardScaler()),
    ('MLPRegressor', MLPRegressor(random_state=42))
])

random_search = RandomizedSearchCV(
    estimator=reg_model,
    param_distributions=param_grid,
    n_iter=10,
    cv=5,
    scoring='r2',
    verbose=1,
    random_state=42
)

random_search.fit(X_train, y_train)

reg_model = random_search.best_estimator_

# use the model to predict values for the test set
y_test_pred = reg_model.predict(X_test)

# build a dataframe with the real, predicted and error values
df_test_pred = pd.DataFrame()
df_test_pred['# passenger'] = y_test
df_test_pred['# pred passenger'] = y_test_pred
df_test_pred['error'] = df_test_pred['# passenger'] - df_test_pred['# pred passenger']
df_test_pred

# %% [markdown]
# ##### Visual inspection
# In addition to numerical metrics, it's important to visually inspect the model's performance. This can include plotting the predicted values against the actual values and examining the residual plots to ensure that the model is capturing the underlying patterns in the data.

# %%
df_test = pd.DataFrame(y_test)
df_test["#Passengers predicted"] =  y_test_pred
df_test.set_index(pd.to_datetime(dict(year=X_test.Year, month=X_test.Month, day=1)), inplace=True)
df_test.plot()

# %% [markdown]
# ### Mean absolute error (MAE)
# The MAE is a common metric used to evaluate time series regression models. It measures the average absolute difference between the predicted values $\hat{y}_t$ and the actual values $y_t$:
# $$\text{MAE} = \frac{1}{n}\sum_{t=1}^{n}|\hat{y}_t - y_t|$$
#
# A lower MAE indicates a more accurate model. Let us see an example.

# %%
# compute the MAE for the test set
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_test_pred)
print('MAE:', mae)

# %% [markdown]
# ### Mean squared error (MSE)
# The MSE is another common metric used to evaluate time series regression models. It measures the average squared difference between the predicted values and the actual values:
# $$\text{MSE} = \frac{1}{n}\sum_{t=1}^{n}(\hat{y}_t - y_t)^2$$
#
# The MSE penalizes large errors more heavily than small errors.

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test, y_test_pred)
print('MSE:', MSE)

# %% [markdown]
# ### Root mean squared error (RMSE)
# The RMSE is the square root of the MSE and is often used as a measure of the model's accuracy. Like the MSE, the RMSE penalizes large errors more heavily than small errors:
# $$\text{RMSE} = \sqrt{\text{MSE}}$$

# %%
RMSE = MSE ** .5
print('RMSE:', RMSE)

# %% [markdown]
# ### Coefficient of determination (R-squared)
# The R-squared value measures the proportion of the variance in the dependent variable that is explained by the independent variables in the model. A higher R-squared value indicates a better fit. It is calculated as follows:
# $$\text{R-squared} = 1 - \frac{\text{SSE}}{\text{SST}}$$
#
# where $\text{SSE}$ is the sum of squared errors and $\text{SST}$ is the total sum of squares:
#
# $$\text{SSE} = \sum_{t=1}^{n}(\hat{y}_t - y_t)^2$$
#
# $$\text{SST} = \sum_{t=1}^{n}(y_t - \bar{y})^2$$
#
# where $\bar{y}$ is the mean of the actual values.

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_test_pred)
print('R2:', R2)

# %% [markdown]
# ## ("Standard") Machine Learning models
#
# Several "standard" machine learning models can be used for time-series regression. In this section, every model is trained and evaluated using the airline passengers series only.
#
# To keep comparisons fair, we will use the same passengers-derived feature matrix and the same chronological holdout split across all methods.

# %%
import numpy as np

# build a passengers-only supervised learning table
passengers_ml = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=['Month'])
passengers_ml = passengers_ml.drop(columns=['Unnamed: 0'], errors='ignore')
passengers_ml = passengers_ml.sort_values('Month').set_index('Month')

passengers_ml['year'] = passengers_ml.index.year
passengers_ml['month_num'] = passengers_ml.index.month
passengers_ml['time_idx'] = range(len(passengers_ml))

# seasonality-aware engineered features
passengers_ml['lag_1'] = passengers_ml['#Passengers'].shift(1)
passengers_ml['lag_12'] = passengers_ml['#Passengers'].shift(12)
passengers_ml['roll_mean_3'] = passengers_ml['#Passengers'].rolling(3).mean()
passengers_ml['roll_mean_12'] = passengers_ml['#Passengers'].rolling(12).mean()
passengers_ml['month_sin'] = np.sin(2 * np.pi * passengers_ml['month_num'] / 12)
passengers_ml['month_cos'] = np.cos(2 * np.pi * passengers_ml['month_num'] / 12)

passengers_ml.head()

# %% [markdown]
# Lagged and rolling features create missing values at the beginning of the series. We remove those rows before fitting the models.

# %%
feature_cols = [
    'year', 'month_num', 'time_idx',
    'lag_1', 'lag_12', 'roll_mean_3', 'roll_mean_12',
    'month_sin', 'month_cos'
]

passengers_ml = passengers_ml.dropna().copy()
passengers_ml.info()

# %%
X = passengers_ml[feature_cols]
y = passengers_ml['#Passengers']

passengers_ml.head()

# %% [markdown]
# We now expand the passengers feature space with polynomial interactions so linear models can capture mild nonlinear effects between trend, seasonality, and lag terms.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features_model = PolynomialFeatures(degree=2, include_bias=False)
X_poly = pd.DataFrame(
    poly_features_model.fit_transform(X),
    columns=poly_features_model.get_feature_names_out(feature_cols),
    index=X.index
)

X_poly.head()

# %% [markdown]
# Now we define a chronological train/test split for passengers forecasting. The last 24 months are held out as unseen test data, and no shuffling is applied.

# %%
test_horizon = 24

# training data
X_train = X_poly.iloc[:-test_horizon]
y_train = y.iloc[:-test_horizon]

# testing data
X_test = X_poly.iloc[-test_horizon:]
y_test = y.iloc[-test_horizon:]

# %% [markdown]
# ### Linear regression
#
# Linear regression is a simple and widely used method for time-series regression. Here, we apply it to monthly airline passengers using engineered trend, seasonal, and lag-based predictors. Four linear variants are shown next.
#
# #### Ordinary Least Squares (OLS):
# OLS is a linear regression method that minimizes the sum of squared residuals (differences between observed and predicted passengers) using a closed-form solution. The mathematical formulation for OLS is:
#
# $$\beta_{OLS} = (X^TX)^{-1}X^Ty$$
#
# where $\beta_{OLS}$ is the vector of coefficients, $X$ is the matrix of independent variables, and $y$ is the vector of passenger counts. The OLS method seeks the values of $\beta$ that minimize the residual sum of squares (RSS):
#
# $$RSS = \sum_{i=1}^n (y_i - \hat{y}_i)^2 = \sum_{i=1}^n \left(y_i - \beta_0 - \sum_{j=1}^p x_{ij}\beta_j\right)^2$$
#
# where $\hat{y}_i$ is the predicted value of $y_i$, $p$ is the number of predictors, and $n$ is the number of observations.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

ols_model = Pipeline([
    ('scaler', StandardScaler()),
    ('OLS', LinearRegression())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = ols_model.predict(X_test)

# %% [markdown]
# Let us define a helper function to present passengers forecasting results in a systematic way.

# %%
def print_results(y_test, y_test_pred, title='Passengers: real vs predicted'):
    from sklearn.metrics import mean_absolute_error
    from sklearn.metrics import mean_squared_error
    from sklearn.metrics import r2_score

    print('Real values:', y_test.values)
    print('Predictions:', y_test_pred)

    mae = mean_absolute_error(y_test, y_test_pred)
    print('MAE:', mae)

    mse = mean_squared_error(y_test, y_test_pred)
    print('MSE:', mse)

    rmse = mse ** 0.5
    print('RMSE:', rmse)

    r2 = r2_score(y_test, y_test_pred)
    print('R2:', r2)

    df_plot = pd.DataFrame({'Passengers': y_test.values, 'Passengers_predicted': y_test_pred}, index=y_test.index)
    ax = df_plot.plot(figsize=(20, 8), title=title)
    ax.set_ylabel('Passengers')

print_results(y_test, y_test_pred)

# %% [markdown]
# #### Lasso
#
# Lasso (Least Absolute Shrinkage and Selection Operator) is a linear regression method that includes a penalty term on the absolute values of the coefficients to encourage sparsity in the model. The mathematical formulation for Lasso is:
#
# $$\beta_{lasso} = argmin_{\beta} \left\{ \frac{1}{n} \sum_{i=1}^n \left(y_i - \beta_0 - \sum_{j=1}^p x_{ij}\beta_j\right)^2 + \lambda \sum_{j=1}^p |\beta_j| \right\}$$
#
# where $\beta_{lasso}$ is the vector of coefficients, $y$ is the vector of dependent variable values, $x_{ij}$ is the value of the $j$-th independent variable for the $i$-th observation, $\lambda$ is the regularization parameter. The Lasso method seeks to find the values of $\beta$ that minimize the following objective function:
#
# $$\min_\beta \frac{1}{n} \sum_{i=1}^n \left(y_i - \beta_0 - \sum_{j=1}^p x_{ij}\beta_j\right)^2 + \lambda \sum_{j=1}^p |\beta_j|$$

# %%
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline

lasso_model = Pipeline([
    ('scaler', StandardScaler()),
    ('Lasso', Lasso())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = lasso_model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# #### Ridge
# Ridge regression is a linear regression method that includes a penalty term on the squared values of the coefficients to prevent overfitting. The mathematical formulation for Ridge is:
#
# $$\hat{\beta}_{ridge} = \arg \min_{\beta} \left\{\sum_{i=1}^{n}(y_i-\beta_0-\sum_{j=1}^{p}x_{ij}\beta_j)^2 + \lambda \sum_{j=1}^{p}\beta_j^2\right\}$$
#
# where $\beta_{ridge}$ is the vector of coefficients, $y$ is the vector of dependent variable values, $x_{ij}$ is the value of the $j$-th independent variable for the $i$-th observation, $\lambda$ is the regularization parameter.

# %%
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline

ridge_model = Pipeline([
    ('scaler', StandardScaler()),
    ('Ridge', Ridge())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = ridge_model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# #### Elastic Net
# Elastic Net is a linear regression method that combines both Lasso and Ridge penalties to achieve both sparsity and prevent overfitting. The mathematical formulation for Elastic Net is:
#
# $$\beta_{elastic} = argmin_{\beta} \left\{ \frac{1}{n} \sum_{i=1}^n (y_i - \beta_0 - \sum_{j=1}^p x_{ij}\beta_j)^2 + \lambda_1 \sum_{j=1}^p |\beta_j| + \lambda_2 \sum_{j=1}^p \beta_j^2 \right\}$$
#
# where $\beta_{elastic}$ is the vector of coefficients, $y$ is the vector of dependent variable values, $x_{ij}$ is the value of the $j$-th independent variable for the $i$-th observation, $\lambda_1$ and $\lambda_2$ are regularization parameters. The Elastic Net method seeks to find the values of $\beta$ that minimize the following objective function:
#
# $$\text{minimize } \frac{1}{2n} \sum_{i=1}^n (y_i - \beta_0 - \sum_{j=1}^p x_{ij}\beta_j)^2 + \lambda_1 \sum_{j=1}^p |\beta_j| + \lambda_2 \sum_{j=1}^p \beta_j^2$$
#
# Note that when $\lambda_1 = 0$ and $\lambda_2 > 0$, Elastic Net reduces to Ridge regression, and when $\lambda_1 > 0$ and $\lambda_2 = 0$, Elastic Net reduces to Lasso regression.

# %%
from sklearn.linear_model import ElasticNet

elasticnet_model = Pipeline([
    ('scaler', StandardScaler()),
    ('ElasticNet', ElasticNet())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = elasticnet_model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# ### Trees based methods
# #### Decision trees
#
# A decision tree is a predictive modeling tool that learns rules from input variables to predict output values. In this notebook, those outputs are monthly airline passenger counts.
#
# At each node, the algorithm chooses the split that most reduces impurity in the target variable. This process continues recursively until a stopping criterion is reached (for example, max depth or minimum samples per leaf).
#
# Decision trees are easy to interpret, but for passengers forecasting they may struggle to extrapolate beyond the range seen in training data, especially when trend growth continues in the holdout horizon.

# %%
from sklearn.tree import DecisionTreeRegressor

model = Pipeline([
    ('scaler', StandardScaler()),
    ('method', DecisionTreeRegressor())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# #### Random forests
#
# Random forest combines many decision trees trained on random subsets of samples and features, then averages their outputs. On passengers data, this can reduce overfitting compared with a single tree.
#
# However, random forests still do not model temporal dynamics explicitly, so their performance depends heavily on the quality of time-aware engineered features (lags, rolling means, and seasonal encodings). Extrapolation beyond observed trend regimes can still be difficult.

# %%
from sklearn.ensemble import RandomForestRegressor

model = Pipeline([
    ('scaler', StandardScaler()),
    ('method', RandomForestRegressor())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# #### Gradient Boosting
# Gradient Boosting is a powerful machine learning technique for building regression and classification models. It is an ensemble method that combines the predictions of multiple weak learners, typically decision trees, to produce a final prediction.
#
# The basic idea of gradient boosting is to sequentially add decision trees to the model, with each tree attempting to correct the errors of the previous trees. At each stage of the algorithm, the model computes the difference between the predicted and actual output values, known as the residual error. The next decision tree is then trained to predict the residual error, rather than the original output values.
#
# The key to gradient boosting's success is the use of gradient descent optimization to iteratively improve the model. After each decision tree is added, the model computes the gradient of the loss function with respect to the predicted output values, and adjusts the model parameters to minimize the loss function. This process is repeated until the model reaches a pre-defined stopping criterion, such as a maximum number of iterations or a minimum improvement in the loss function.

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = Pipeline([
    ('scaler', StandardScaler()),
    ('method', GradientBoostingRegressor())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# ### Support vector machines (SVM)
# SVM regression is also applicable to airline passengers forecasting when we provide time-aware predictors. It estimates a function in a transformed feature space and can model nonlinear relations between seasonal/trend features and passenger demand.
#
# The penalty parameter `C` controls the trade-off between fit and regularization. For this notebook we keep defaults for illustration, but in practice SVM performance on passengers data depends strongly on hyperparameter tuning and kernel choice.

# %%
from sklearn.svm import SVR

model = Pipeline([
    ('scaler', StandardScaler()),
    ('method', SVR())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# ### Neural networks
#
# MLP (Multi-Layer Perceptron) can capture nonlinear interactions in the passengers feature set, such as interactions between lagged demand and seasonal position in the year.
#
# An MLP maps engineered inputs through hidden layers and learns weights via backpropagation. As with other methods in this notebook, we use it as a baseline; stronger performance usually requires careful tuning of network architecture and regularization.

# %%
from sklearn.neural_network import MLPRegressor

model = Pipeline([
    ('scaler', StandardScaler()),
    ('method', MLPRegressor())
]).fit(X_train, y_train)

# use the model to predict values for the test set
y_test_pred = model.predict(X_test)

print_results(y_test, y_test_pred)

# %% [markdown]
# ## Long Short-Term Memory
# LSTM (Long Short-Term Memory) is a recurrent neural network architecture that can model long-range temporal dependencies in the airline passengers series.
#
# Here we use the previous 12 months to predict the next month of passenger demand. This window length is natural for monthly data because it captures yearly seasonality.
#
# Unlike the previous section (which uses tabular engineered features), LSTM directly consumes ordered sequences, making it a useful baseline for sequence-aware forecasting on passengers data.

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# load passengers series
lstm_df = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=['Month'])
lstm_df = lstm_df.drop(columns=['Unnamed: 0'], errors='ignore').sort_values('Month')

lstm_df['month_num'] = lstm_df['Month'].dt.month
lstm_df['month_sin'] = np.sin(2 * np.pi * lstm_df['month_num'] / 12)
lstm_df['month_cos'] = np.cos(2 * np.pi * lstm_df['month_num'] / 12)

lstm_target = lstm_df['#Passengers'].astype(float)
lstm_feature_df = pd.DataFrame({
    'passengers': lstm_target,
    'month_sin': lstm_df['month_sin'],
    'month_cos': lstm_df['month_cos']
})

lstm_feature_df.head()

# %%
# use previous 12 months to predict the next month
window_size = 12
values = lstm_feature_df.values

X_lstm = np.array([values[i:i + window_size] for i in range(len(values) - window_size)])
y_lstm = lstm_target.iloc[window_size:].copy()
y_lstm.index = lstm_df['Month'].iloc[window_size:]

# split chronologically: train, validation, and test
n_test = 24
n_val = 12

X_train_lstm = X_lstm[:-(n_val + n_test)]
y_train_lstm = y_lstm.iloc[:-(n_val + n_test)]

X_val_lstm = X_lstm[-(n_val + n_test):-n_test]
y_val_lstm = y_lstm.iloc[-(n_val + n_test):-n_test]

X_test_lstm = X_lstm[-n_test:]
y_test_lstm = y_lstm.iloc[-n_test:]

# scale each feature with train-only statistics to avoid leakage
x_scaler = StandardScaler()
X_train_2d = X_train_lstm.reshape(-1, X_train_lstm.shape[-1])
x_scaler.fit(X_train_2d)

def scale_sequences(X_in, scaler):
    X2d = X_in.reshape(-1, X_in.shape[-1])
    X_scaled = scaler.transform(X2d)
    return X_scaled.reshape(X_in.shape)

X_train_lstm = scale_sequences(X_train_lstm, x_scaler)
X_val_lstm = scale_sequences(X_val_lstm, x_scaler)
X_test_lstm = scale_sequences(X_test_lstm, x_scaler)

X_train_lstm.shape, X_val_lstm.shape, X_test_lstm.shape

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler

# reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# scale target with train-only statistics
y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train_lstm.values.reshape(-1, 1)).ravel()
y_val_scaled = y_scaler.transform(y_val_lstm.values.reshape(-1, 1)).ravel()

lstm_model = keras.Sequential([
    keras.Input(shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])),
    layers.LSTM(64, dropout=0.2),
    layers.Dense(1)
])

lstm_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    loss='huber'
)

callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
]

hist = lstm_model.fit(
    X_train_lstm,
    y_train_scaled,
    epochs=240,
    batch_size=32,
    validation_data=(X_val_lstm, y_val_scaled),
    callbacks=callbacks,
    shuffle=False,
    verbose=1,
)

y_test_pred_scaled = lstm_model.predict(X_test_lstm).ravel()
y_test_pred = y_scaler.inverse_transform(y_test_pred_scaled.reshape(-1, 1)).ravel()

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Huber Loss')
plt.legend(['train', 'validation'])
plt.show()

# %%
print_results(y_test_lstm, y_test_pred, title='Passengers LSTM: real vs predicted')

# %% [markdown]
# ### Seasonal naive baseline (strong benchmark)
# Before trusting a deep model on a short monthly series, compare it with a seasonal naive baseline: predict each month using the value from 12 months earlier.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

full_passengers = lstm_df.set_index('Month')['#Passengers'].astype(float)
y_naive_pred = full_passengers.shift(12).loc[y_test_lstm.index]

naive_mae = mean_absolute_error(y_test_lstm, y_naive_pred)
naive_rmse = mean_squared_error(y_test_lstm, y_naive_pred) ** 0.5
naive_r2 = r2_score(y_test_lstm, y_naive_pred)

lstm_mae = mean_absolute_error(y_test_lstm, y_test_pred)
lstm_rmse = mean_squared_error(y_test_lstm, y_test_pred) ** 0.5
lstm_r2 = r2_score(y_test_lstm, y_test_pred)

print('Seasonal naive (t-12) -> MAE:', round(naive_mae, 3), 'RMSE:', round(naive_rmse, 3), 'R2:', round(naive_r2, 3))
print('LSTM                -> MAE:', round(lstm_mae, 3), 'RMSE:', round(lstm_rmse, 3), 'R2:', round(lstm_r2, 3))

# %% [markdown]
# ### Conclusion
# For the airline passengers series, different regression families capture different parts of the signal: linear models provide strong baselines, tree ensembles can model nonlinearities, and LSTM can learn sequence structure directly.
#
# Model quality depends on feature design, hyperparameter tuning, and leakage-free validation. In particular, lag and seasonal features are essential for tabular models on monthly passengers data.
#
# A robust next step is rolling-origin time-series cross-validation, which better reflects real forecasting usage than a single split and provides more stable estimates of out-of-sample passenger forecasting performance.

# %% [markdown]
# ##  Autoregressive Integrated Moving Average models
#
# ARIMA (Autoregressive Integrated Moving Average) models are a popular class of time series models used for forecasting, having numerous applications in a variety of industries. It is widely used in demand forecasting, such as predicting future demand in the food industry.
#
# There are several variants of ARIMA models, such as:
#
# - __Seasonal ARIMA (SARIMA) models__: These models are an extension of ARIMA models that take into account the seasonal component of a time series. SARIMA models incorporate seasonal differences, seasonal autoregressive (SAR) terms, and seasonal moving average (SMA) terms in addition to the non-seasonal terms of an ARIMA model.
#
# - __ARIMA with exogenous variables (ARIMAX)__: These models are an extension of ARIMA models that include additional independent variables, also known as exogenous variables, that may be useful in predicting the time series. ARIMAX models can be useful when there are external factors that influence the time series.
#
# The choice of which model to use depends on the specific characteristics of the time series being modeled and the nature of the forecasting problem.

# %% [markdown]
# ### ARIMA
#
# ARIMA (Auto-Regressive Integrated Moving Average) is a classical approach for forecasting the airline passengers time series after making it stationary (typically via differencing).
#
# A **stationary time series** has statistical properties that remain approximately constant over time. For passengers data, long-term growth and seasonality often violate stationarity, so differencing is usually required.
#
# An ARIMA model can be interpreted as a filter that separates structured signal from noise before forecasting future passenger values.
#
# The ARIMA forecasting equation is linear in lagged values of the series and lagged forecast errors:
#
# __Predicted passengers = constant + weighted recent passengers + weighted recent forecast errors__
#
# In this equation, lagged observations are **autoregressive (AR)** terms, lagged errors are **moving-average (MA)** terms, and differencing operations correspond to the **integrated (I)** part.

# %% [markdown]
# For the passengers series, an
# $$ARIMA(p, d, q)$$
# model has the following interpretation:
#
# - $p$: number of lagged passenger observations used as predictors.
# - $d$: differencing order needed to remove trend and approach stationarity.
# - $q$: number of lagged forecast errors included to capture remaining autocorrelation.
#
# Because monthly airline demand is seasonal, SARIMA is often more appropriate in practice. We keep ARIMA here as the core baseline and evaluate it directly on the passengers holdout horizon.

# %% [markdown]
# ### Making a series stationary
#
# For airline passengers, stationarity is usually obtained by differencing because the raw series has clear upward trend and seasonality. Differencing means subtracting the previous value from the current one.
#
# The value of $d$ in ARIMA is the smallest differencing order that yields an approximately stationary series. If the passenger series were already stationary, then $d=0$.

# %% [markdown]
# ### Pure Auto Regressive
# A pure Auto-Regressive model, $AR(p)$, predicts current passenger demand from its own previous values:
#
# $$Y_t = \alpha + \beta_1 Y_{t-1} + \beta_2 Y_{t-2} + \cdots + \beta_p Y_{t-p} + \epsilon_t
# = \alpha + \sum_{i=1}^p \beta_i Y_{t-i} + \epsilon_t $$
#
# where $Y_{t-i}$ are lagged passenger observations and $\beta_i$ are learned coefficients.

# %% [markdown]
# ### Pure Moving Average
# A pure Moving Average model, $MA(q)$, explains passenger values using current and lagged forecast errors:
#
# $$ Y_t = \alpha + \epsilon_t + \phi_1 \epsilon_{t-1} + \phi_2 \epsilon_{t-2} + \cdots + \phi_q \epsilon_{t-q}
# = \alpha + \epsilon_t + \sum_{i=1}^q \phi_i \epsilon_{t-i} $$
#
# where the error terms are treated as white noise.

# %% [markdown]
# ### ARMA
#
# An $ARMA(p,q)$ model combines autoregressive and moving-average components for passengers forecasting:
#
# $$Y_t =  \alpha + \epsilon_t + \sum_{i=1}^q \phi_i \epsilon_{t-i} + \sum_{i=1}^p \beta_i Y_{t-i}$$

# %% [markdown]
# ### Autoregression + Integrated + Moving average
#
# For the monthly airline passengers series, ARIMA combines:
#
# - AR (Autoregression): dependence on prior passenger values.
# - I (Integrated): differencing to handle non-stationary trend/seasonality.
# - MA (Moving average): dependence on previous forecast errors.
#
# Additional reading: [https://online.stat.psu.edu/stat510/book/export/html/665](https://online.stat.psu.edu/stat510/book/export/html/665)

# %% [markdown]
# In the airline passengers series, the rolling mean still shows trend while the rolling standard deviation is comparatively more stable.
#
# For stationarity, both rolling mean and rolling standard deviation should remain roughly constant over time. Since that is not the case here, differencing is justified before fitting ARIMA.

# %% [markdown]
# ## Useful libraries
#
# For airline passengers forecasting, these libraries are particularly useful:
#
# - pandas: data loading, datetime indexing, lag/rolling feature engineering.
# - numpy: vectorized numerical operations and seasonal encodings.
# - statsmodels: classical time-series models such as ARIMA/SARIMA.
# - scikit-learn: regression baselines and evaluation metrics for engineered passengers features.
# - prophet: additive trend/seasonality forecasting model for monthly passengers.
#
# These libraries can be combined to prepare data, train models, compare metrics, and visualize passenger forecasts.

# %%
import statsmodels.api as sm
import pandas as pd

# load airline passengers data
df_passengers = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=['Month']).drop(columns=['Unnamed: 0'], errors='ignore')
series = df_passengers.set_index('Month')['#Passengers']

# quick ARIMA example
model = sm.tsa.arima.ARIMA(series, order=(1, 1, 1)).fit()
print(model.summary())

# %%
# ARIMA model selection with proper time-based split (airline passengers)
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error

# load passengers series
df_passengers = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=['Month']).drop(columns=['Unnamed: 0'], errors='ignore')
series = df_passengers.set_index('Month')['#Passengers']

# chronological train/test split (no leakage)
horizon = 24
train = series.iloc[:-horizon]
test = series.iloc[-horizon:]

# search best ARIMA(p,d,q) on train only
p_range = range(0, 4)
d_range = range(0, 3)
q_range = range(0, 4)

best_order = None
best_model = None
best_aic = float('inf')

for p in p_range:
    for d in d_range:
        for q in q_range:
            try:
                model = sm.tsa.arima.ARIMA(train, order=(p, d, q)).fit()
                if model.aic < best_aic:
                    best_aic = model.aic
                    best_order = (p, d, q)
                    best_model = model
            except Exception:
                continue

print(f'Best ARIMA order (train AIC): {best_order}')
print(f'Best train AIC: {best_aic:.2f}')
print(best_model.summary())

# evaluate on unseen test horizon
forecast = best_model.forecast(steps=len(test))
mae = mean_absolute_error(test, forecast)
rmse = np.sqrt(mean_squared_error(test, forecast))
mape = np.mean(np.abs((test - forecast) / test.replace(0, np.nan))) * 100

print(f'Test MAE:  {mae:.4f}')
print(f'Test RMSE: {rmse:.4f}')
print(f'Test MAPE: {mape:.2f}%')

# %%
# Forecast plotting (real vs predicted only)
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))
plt.plot(test.index, test.values, label='Real (Test)', alpha=0.9, marker='o')
plt.plot(test.index, forecast.values, label='Predicted (ARIMA)', linestyle='--', linewidth=2, marker='o')

plt.title(f'ARIMA: Real vs Predicted (order={best_order})')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Prophet
#
# Prophet is an additive forecasting model that handles trend and seasonality well, which makes it a good candidate for the airline passengers time series.
#
# In this notebook, we fit Prophet on the passengers training period and evaluate it on the same holdout horizon used by ARIMA for a fair comparison.

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# import airline passenger data
df = pd.read_csv('./data/passengers_TS/passengers.csv', parse_dates=['Month']).drop(columns=['Unnamed: 0'], errors='ignore')

# prophet requires columns ds (Date) and y (value)
df = df.rename(columns={'Month': 'ds', '#Passengers': 'y'})

# hold out the last 24 months for evaluation
horizon = 24
train_df = df.iloc[:-horizon].copy()
test_df = df.iloc[-horizon:].copy()

m = Prophet(
    
)
m.fit(train_df)

# forecast through the test horizon
future = m.make_future_dataframe(periods=horizon, freq='MS')
forecast = m.predict(future)

# plot forecast
m.plot(forecast)
plt.title('Prophet forecast (train + predicted horizon)')
plt.show()

m.plot_components(forecast)
plt.show()

# %%
# Compare real vs predicted values on the test horizon
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

pred_test = forecast[['ds', 'yhat']].tail(horizon).copy()
comparison = test_df[['ds', 'y']].merge(pred_test, on='ds', how='left')

mae = mean_absolute_error(comparison['y'], comparison['yhat'])
rmse = np.sqrt(mean_squared_error(comparison['y'], comparison['yhat']))
mape = np.mean(np.abs((comparison['y'] - comparison['yhat']) / comparison['y'])) * 100

print(f'Test MAE:  {mae:.2f}')
print(f'Test RMSE: {rmse:.2f}')
print(f'Test MAPE: {mape:.2f}%')

plt.figure(figsize=(12, 5))
plt.plot(comparison['ds'], comparison['y'], label='Real', marker='o')
plt.plot(comparison['ds'], comparison['yhat'], label='Predicted (Prophet)', linestyle='--', marker='o')
plt.title('Prophet: Real vs Predicted (Test Horizon)')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Prophet hyperparameter tuning with rolling cross-validation
# -----------------------------------------------------------
# Goal:
#   1) Search a small grid of Prophet hyperparameters.
#   2) Evaluate each combination using time-series cross-validation.
#   3) Select the best combination by RMSE.
#   4) Refit the model on train_df and evaluate on the fixed holdout test_df.
#   5) Plot observed vs predicted values for visual inspection.

from itertools import product
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics

# Hyperparameter grid (small but practical for class/demo speed)
# - changepoint_prior_scale: controls trend flexibility (higher -> more flexible)
# - seasonality_prior_scale: regularization strength for seasonality terms
# - seasonality_mode: additive vs multiplicative seasonality behavior
param_grid = {
    'changepoint_prior_scale': [0.01, 0.05, 0.1],
    'seasonality_prior_scale': [1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Build all combinations from the grid.
# Example: 3 * 2 * 2 = 12 total model configurations.
all_params = [dict(zip(param_grid.keys(), v)) for v in product(*param_grid.values())]

# We store CV metrics for each configuration here.
results = []

# Loop over each hyperparameter combination, train Prophet, and cross-validate.
for params in all_params:
    # Keep yearly seasonality active (monthly airline data),
    # and disable weekly/daily components because they are not meaningful here.
    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        **params
    )

    # Fit using only the training subset defined earlier in the notebook.
    model.fit(train_df)

    # Rolling-origin CV (time-aware validation):
    # - initial: first training window used for the first fit
    # - period: spacing between cutoff dates
    # - horizon: forecast length for each fold
    # We keep ~1 year horizon to mimic the holdout task.
    cv_df = cross_validation(
        model,
        initial='1825 days',   # about 5 years initial history
        period='180 days',
        horizon='365 days',
        parallel=None
    )

    # Aggregate fold metrics.
    # rolling_window=1 returns metrics over the full CV output.
    perf = performance_metrics(cv_df, rolling_window=1)

    # Save metrics + parameters so we can rank all models later.
    results.append({
        **params,
        'rmse': perf['rmse'].iloc[0],
        'mape': perf['mape'].iloc[0],
        'mae': perf['mae'].iloc[0]
    })

# Create a table and sort by RMSE (lower is better).
results_df = pd.DataFrame(results).sort_values('rmse').reset_index(drop=True)
print('Top hyperparameter combinations (sorted by RMSE):')
print(results_df.head())

# Select the best parameter set (first row after sorting).
best_params = results_df.loc[
    0,
    ['changepoint_prior_scale', 'seasonality_prior_scale', 'seasonality_mode']
].to_dict()
print('\nBest params:', best_params)

# Refit Prophet with the best parameters on the full training set.
best_model = Prophet(
    yearly_seasonality=True,
    weekly_seasonality=False,
    daily_seasonality=False,
    **best_params
)
best_model.fit(train_df)

# Forecast through the same holdout horizon used before.
future_best = best_model.make_future_dataframe(periods=horizon, freq='MS')
forecast_best = best_model.predict(future_best)

# Keep only predicted points that correspond to the holdout months.
pred_test_best = forecast_best[['ds', 'yhat']].tail(horizon).copy()
comparison_best = test_df[['ds', 'y']].merge(pred_test_best, on='ds', how='left')

# Compute final holdout metrics for the tuned model.
mae_best = mean_absolute_error(comparison_best['y'], comparison_best['yhat'])
rmse_best = np.sqrt(mean_squared_error(comparison_best['y'], comparison_best['yhat']))
mape_best = np.mean(np.abs((comparison_best['y'] - comparison_best['yhat']) / comparison_best['y'])) * 100

print(f'\nHoldout MAE (best):  {mae_best:.2f}')
print(f'Holdout RMSE (best): {rmse_best:.2f}')
print(f'Holdout MAPE (best): {mape_best:.2f}%')

# Plot observed vs tuned predictions on the holdout period.
# This visual check complements MAE/RMSE/MAPE by showing trend/seasonal alignment.
plt.figure(figsize=(12, 5))
plt.plot(comparison_best['ds'], comparison_best['y'], label='Observed', marker='o')
plt.plot(
    comparison_best['ds'],
    comparison_best['yhat'],
    label='Predicted (Prophet tuned)',
    linestyle='--',
    marker='o'
)
plt.title('Prophet tuned: Observed vs Predicted (Holdout)')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
