# %% [markdown]
# # Layouts
#
# Panel provides a number of different layout options for arranging components in a dashboard. The most common layout is the `Row` and `Column` layout, which allow you to arrange components horizontally or vertically. However, Panel also provides a number of other layout options, including `Tabs`, `GridSpec`, `Accordion`, and `Card`.
#
#
# ![](images/layouts.png)
#
# https://panel.holoviz.org/reference/index.html#layouts
#
# In this notebook, we will explore some of these different layout options and see how they can be used to create more complex and interactive dashboards.

# %% [markdown]
# ## Column Layout
#
# In the Column layout
#
# [src/02_layouts_column.py](src/02_layouts_column.py)
#
# To run the script, move
#
# ```

# %%
1+1
# Out:
# 2
